# %%
# #1
# class Song:
#     def __init__ (self, titol, autor, durada):
#         self.titol = titol
#         self.autor = autor
#         self.durada= durada

#     def info(self):
#         return f"{self.titol} - {self.autor}({self.durada}s)"
    
# class Playlist:
#     def __init__(self, song_list):
#         self.song_list = song_list
    
#     def afegir_canço(self, song):
#         self.song_list.append(song)
    
#     def durada_total(self, song_list):
#         durada_total = 0
#         for i in song_list:
#             durada_total += i.durada
#         print(durada_total)
#         return durada_total
    
#     def mostrar_playlist(self, song_list):
#         playlist= []
#         for i in song_list:
#             playlist.append(i.info())
#         print(playlist)
#         return playlist
    
#     def canço_mes_llarga(self, song_list):
#         durada_max = 0
#         cançomesllarga = "" 
#         for i in song_list:
#             if i.durada > durada_max:
#                 durada_max = i.durada
#                 cançomesllarga = i

#             else:
#                 pass
#         print(cançomesllarga)
#         return cançomesllarga.info()
        


        

    



# canço1 = Song("canço1", "autor1", 100)
# canço2 = Song("canço2", "autor2", 150)
# song_list = [canço1, canço2]
# playlistbet = Playlist(song_list)
# canço3 = Song("canço3", "autor3", 200)
# playlistbet.afegir_canço(canço3)
# playlistbet.durada_total(song_list)
# playlistbet.mostrar_playlist(song_list)
# playlistbet.canço_mes_llarga(song_list)
# Out:
# 450
# ['canço1 - autor1(100s)', 'canço2 - autor2(150s)', 'canço3 - autor3(200s)']
# ...
# 'canço3 - autor3(200s)'

# %%
#2
class Personatge:
    def __init__(self, nom, vida, forca, nivell):
        self.nom = nom
        self.vida = vida
        self.forca = forca
        self.nivell = nivell
    
    def atacar(self, enemic):
        if enemic.vida > self.forca:
            enemic.vida -= self.forca
            print(f"l'enemic té vida : {enemic.vida}")
        else:
            self.vida = 0
            print("no es pot restar mes vida que la que el personatge té")

    def pujar_nivell(self):
        self.nivell+=1
        self.forca+=2
        self.vida+=5
        print(f"El personatge està en el nivell {self.nivell}, té {self.forca} de força i {self.vida} de vida")
    
    def esta_viu(self):
        if self.vida>0:
            return True
        else:
            return False
        
    def __str__(self):
        return f"El personatge {self.nom} té {self.vida} de vida, fa {self.forca} de força i està al nivell {self.nivell}"


Mario = Personatge("Mario", 200, 100, 3)
Louigi = Personatge("Louigi", 300, 50, 3)
while True:
    Mario.atacar(Louigi)
    if Louigi.esta_viu == True:
        pass
    else:
        print("Louigi ha mort")
        guanyador = Mario
        break
    Louigi.atacar(Mario)
    if Mario.esta_viu == True:
        pass
    else:
        print("Mario ha mort")
        guanyador = Louigi
        break

guanyador.pujar_nivell()
print(guanyador)
# Out:
# l'enemic té vida : 200
# Louigi ha mort
# El personatge està en el nivell 4, té 102 de força i 205 de vida
# El personatge Mario té 205 de vida, fa 102 de força i està al nivell 4

# %%
#Extra
class SistemaEquacions:
    def __init__(self, matriu):
        self.matriu = matriu

    def metodedeGauss(self):
        


matriu = [1,1,1
          2,-1,1
          1,2-1]
# Out:
#   Cell In[11], line 9
#     matriu = (1,1,1
#                    ^
# IndentationError: expected an indented block after function definition on line 6
